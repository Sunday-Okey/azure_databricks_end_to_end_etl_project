# %%
# %sql
USE CATALOG databricksdemo;
USE SCHEMA silver;

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df = spark.table('databricksdemo.bronze.regions')\
    .drop("_rescued_data")
display(df)

# %%
df.write.format("delta")\
    .mode("overwrite")\
    .save("abfss://silver@storageaccountsunnybest.dfs.core.windows.net/regions")

# %%
# %sql
CREATE TABLE IF NOT EXISTS regions_silver
USING delta
LOCATION 'abfss://silver@storageaccountsunnybest.dfs.core.windows.net/regions'

# %%
# %sql
SELECT *
FROM regions_silver
