# %%
datasets = [
    {
        'file_name': 'customers'
    },
    {
        'file_name': 'orders'
    },
    {
        'file_name': 'regions'
    },
    {
        'file_name': 'products'
    }
]

# %%
# dbutils.jobs.taskValues.get()

# %%
dbutils.jobs.taskValues.set("output_datasets", datasets)
